# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt

from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

np.set_printoptions(threshold=np.inf)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv('./datasets/diabetes.csv')

x = df.drop('Outcome', axis=1)
t = df['Outcome']

x_train, x_test, t_train, t_test = train_test_split(x, t, train_size=.7, test_size=.3, shuffle=True)

# %%
model = linear_model.LinearRegression()
model.fit(x_train, t_train)
# Out:
# LinearRegression()

# %%
y_test=model.predict(x_test)
mean_squared_error(y_test, t_test)
# Out:
# 0.15004673054124681

# %%
model = linear_model.Ridge()
model.fit(x_train, t_train)
# Out:
# Ridge()

# %%
y_test=model.predict(x_test)
mean_squared_error(y_test, t_test)
# Out:
# 0.15008795131824795

# %%
model = linear_model.Lasso()
model.fit(x_train, t_train)
# Out:
# Lasso()

# %%
y_test=model.predict(x_test)
mean_squared_error(y_test, t_test)
# Out:
# 0.16898328528620285

# %%
model = linear_model.BayesianRidge()
model.fit(x_train, t_train)
# Out:
# BayesianRidge()

# %%
y_test=model.predict(x_test)
mean_squared_error(y_test, t_test)
# Out:
# 0.15407425505629188

# %%
model = linear_model.LogisticRegression(
  solver="liblinear",
  max_iter=int(1e6)
)
model.fit(x_train, t_train)
# Out:
# LogisticRegression(max_iter=1000000, solver='liblinear')

# %%
y_test=model.predict(x_test)
mean_squared_error(y_test, t_test)
# Out:
# 0.20346320346320346

# %%
model = linear_model.SGDRegressor(
  max_iter=int(1e6),
  alpha=0.0001,
  validation_fraction=.3
)

model.fit(x_train, t_train)
# Out:
# SGDRegressor(max_iter=1000000, validation_fraction=0.3)

# %%
y_test=model.predict(x_test)
'%f' % mean_squared_error(y_test, t_test)
# Out:
# '294853954367910422666805248.000000'
